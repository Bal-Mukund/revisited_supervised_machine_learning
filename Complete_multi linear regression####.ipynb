# %%
import numpy as np
import matplotlib.pyplot as plt
import copy

# %%
X_features = ['size(sqft)','bedrooms','floors','age']

X_train = np.array([[1.24e+03, 3.00e+00, 1.00e+00, 6.40e+01],
       [1.95e+03, 3.00e+00, 2.00e+00, 1.70e+01],
       [1.72e+03, 3.00e+00, 2.00e+00, 4.20e+01],
       [1.96e+03, 3.00e+00, 2.00e+00, 1.50e+01],
       [1.31e+03, 2.00e+00, 1.00e+00, 1.40e+01],
       [8.64e+02, 2.00e+00, 1.00e+00, 6.60e+01],
       [1.84e+03, 3.00e+00, 1.00e+00, 1.70e+01],
       [1.03e+03, 3.00e+00, 1.00e+00, 4.30e+01],
       [3.19e+03, 4.00e+00, 2.00e+00, 8.70e+01],
       [7.88e+02, 2.00e+00, 1.00e+00, 8.00e+01],
       [1.20e+03, 2.00e+00, 2.00e+00, 1.70e+01],
       [1.56e+03, 2.00e+00, 1.00e+00, 1.80e+01],
       [1.43e+03, 3.00e+00, 1.00e+00, 2.00e+01],
       [1.22e+03, 2.00e+00, 1.00e+00, 1.50e+01],
       [1.09e+03, 2.00e+00, 1.00e+00, 6.40e+01],
       [8.48e+02, 1.00e+00, 1.00e+00, 1.70e+01],
       [1.68e+03, 3.00e+00, 2.00e+00, 2.30e+01],
       [1.77e+03, 3.00e+00, 2.00e+00, 1.80e+01],
       [1.04e+03, 3.00e+00, 1.00e+00, 4.40e+01],
       [1.65e+03, 2.00e+00, 1.00e+00, 2.10e+01],
       [1.09e+03, 2.00e+00, 1.00e+00, 3.50e+01],
       [1.32e+03, 3.00e+00, 1.00e+00, 1.40e+01],
       [1.59e+03, 0.00e+00, 1.00e+00, 2.00e+01],
       [9.72e+02, 2.00e+00, 1.00e+00, 7.30e+01],
       [1.10e+03, 3.00e+00, 1.00e+00, 3.70e+01],
       [1.00e+03, 2.00e+00, 1.00e+00, 5.10e+01],
       [9.04e+02, 3.00e+00, 1.00e+00, 5.50e+01],
       [1.69e+03, 3.00e+00, 1.00e+00, 1.30e+01],
       [1.07e+03, 2.00e+00, 1.00e+00, 1.00e+02],
       [1.42e+03, 3.00e+00, 2.00e+00, 1.90e+01],
       [1.16e+03, 3.00e+00, 1.00e+00, 5.20e+01],
       [1.94e+03, 3.00e+00, 2.00e+00, 1.20e+01],
       [1.22e+03, 2.00e+00, 2.00e+00, 7.40e+01],
       [2.48e+03, 4.00e+00, 2.00e+00, 1.60e+01],
       [1.20e+03, 2.00e+00, 1.00e+00, 1.80e+01],
       [1.84e+03, 3.00e+00, 2.00e+00, 2.00e+01],
       [1.85e+03, 3.00e+00, 2.00e+00, 5.70e+01],
       [1.66e+03, 3.00e+00, 2.00e+00, 1.90e+01],
       [1.10e+03, 2.00e+00, 2.00e+00, 9.70e+01],
       [1.78e+03, 3.00e+00, 2.00e+00, 2.80e+01],
       [2.03e+03, 4.00e+00, 2.00e+00, 4.50e+01],
       [1.78e+03, 4.00e+00, 2.00e+00, 1.07e+02],
       [1.07e+03, 2.00e+00, 1.00e+00, 1.00e+02],
       [1.55e+03, 3.00e+00, 1.00e+00, 1.60e+01],
       [1.95e+03, 3.00e+00, 2.00e+00, 1.60e+01],
       [1.22e+03, 2.00e+00, 2.00e+00, 1.20e+01],
       [1.62e+03, 3.00e+00, 1.00e+00, 1.60e+01],
       [8.16e+02, 2.00e+00, 1.00e+00, 5.80e+01],
       [1.35e+03, 3.00e+00, 1.00e+00, 2.10e+01],
       [1.57e+03, 3.00e+00, 1.00e+00, 1.40e+01],
       [1.49e+03, 3.00e+00, 1.00e+00, 5.70e+01],
       [1.51e+03, 2.00e+00, 1.00e+00, 1.60e+01],
       [1.10e+03, 3.00e+00, 1.00e+00, 2.70e+01],
       [1.76e+03, 3.00e+00, 2.00e+00, 2.40e+01],
       [1.21e+03, 2.00e+00, 1.00e+00, 1.40e+01],
       [1.47e+03, 3.00e+00, 2.00e+00, 2.40e+01],
       [1.77e+03, 3.00e+00, 2.00e+00, 8.40e+01],
       [1.65e+03, 3.00e+00, 1.00e+00, 1.90e+01],
       [1.03e+03, 3.00e+00, 1.00e+00, 6.00e+01],
       [1.12e+03, 2.00e+00, 2.00e+00, 1.60e+01],
       [1.15e+03, 3.00e+00, 1.00e+00, 6.20e+01],
       [8.16e+02, 2.00e+00, 1.00e+00, 3.90e+01],
       [1.04e+03, 3.00e+00, 1.00e+00, 2.50e+01],
       [1.39e+03, 3.00e+00, 1.00e+00, 6.40e+01],
       [1.60e+03, 3.00e+00, 2.00e+00, 2.90e+01],
       [1.22e+03, 3.00e+00, 1.00e+00, 6.30e+01],
       [1.07e+03, 2.00e+00, 1.00e+00, 1.00e+02],
       [2.60e+03, 4.00e+00, 2.00e+00, 2.20e+01],
       [1.43e+03, 3.00e+00, 1.00e+00, 5.90e+01],
       [2.09e+03, 3.00e+00, 2.00e+00, 2.60e+01],
       [1.79e+03, 4.00e+00, 2.00e+00, 4.90e+01],
       [1.48e+03, 3.00e+00, 2.00e+00, 1.60e+01],
       [1.04e+03, 3.00e+00, 1.00e+00, 2.50e+01],
       [1.43e+03, 3.00e+00, 1.00e+00, 2.20e+01],
       [1.16e+03, 3.00e+00, 1.00e+00, 5.30e+01],
       [1.55e+03, 3.00e+00, 2.00e+00, 1.20e+01],
       [1.98e+03, 3.00e+00, 2.00e+00, 2.20e+01],
       [1.06e+03, 3.00e+00, 1.00e+00, 5.30e+01],
       [1.18e+03, 2.00e+00, 1.00e+00, 9.90e+01],
       [1.36e+03, 2.00e+00, 1.00e+00, 1.70e+01],
       [9.60e+02, 3.00e+00, 1.00e+00, 5.10e+01],
       [1.46e+03, 3.00e+00, 2.00e+00, 1.60e+01],
       [1.45e+03, 3.00e+00, 2.00e+00, 2.50e+01],
       [1.21e+03, 2.00e+00, 1.00e+00, 1.50e+01],
       [1.55e+03, 3.00e+00, 2.00e+00, 1.60e+01],
       [8.82e+02, 3.00e+00, 1.00e+00, 4.90e+01],
       [2.03e+03, 4.00e+00, 2.00e+00, 4.50e+01],
       [1.04e+03, 3.00e+00, 1.00e+00, 6.20e+01],
       [1.62e+03, 3.00e+00, 1.00e+00, 1.60e+01],
       [8.03e+02, 2.00e+00, 1.00e+00, 8.00e+01],
       [1.43e+03, 3.00e+00, 2.00e+00, 2.10e+01],
       [1.66e+03, 3.00e+00, 1.00e+00, 6.10e+01],
       [1.54e+03, 3.00e+00, 1.00e+00, 1.60e+01],
       [9.48e+02, 3.00e+00, 1.00e+00, 5.30e+01],
       [1.22e+03, 2.00e+00, 2.00e+00, 1.20e+01],
       [1.43e+03, 2.00e+00, 1.00e+00, 4.30e+01],
       [1.66e+03, 3.00e+00, 2.00e+00, 1.90e+01],
       [1.21e+03, 3.00e+00, 1.00e+00, 2.00e+01],
       [1.05e+03, 2.00e+00, 1.00e+00, 6.50e+01]])

y_train = np.array([300.  , 509.8 , 394.  , 540.  , 415.  , 230.  , 560.  , 294.  ,
       718.2 , 200.  , 302.  , 468.  , 374.2 , 388.  , 282.  , 311.8 ,
       401.  , 449.8 , 301.  , 502.  , 340.  , 400.28, 572.  , 264.  ,
       304.  , 298.  , 219.8 , 490.7 , 216.96, 368.2 , 280.  , 526.87,
       237.  , 562.43, 369.8 , 460.  , 374.  , 390.  , 158.  , 426.  ,
       390.  , 277.77, 216.96, 425.8 , 504.  , 329.  , 464.  , 220.  ,
       358.  , 478.  , 334.  , 426.98, 290.  , 463.  , 390.8 , 354.  ,
       350.  , 460.  , 237.  , 288.3 , 282.  , 249.  , 304.  , 332.  ,
       351.8 , 310.  , 216.96, 666.34, 330.  , 480.  , 330.3 , 348.  ,
       304.  , 384.  , 316.  , 430.4 , 450.  , 284.  , 275.  , 414.  ,
       258.  , 378.  , 350.  , 412.  , 373.  , 225.  , 390.  , 267.4 ,
       464.  , 174.  , 340.  , 430.  , 440.  , 216.  , 329.  , 388.  ,
       390.  , 356.  , 257.8 ])

# %%
def graphing(x, y):
    for i in range(x.shape[1]):
        x_plot = x[: , i]
        y_plot = y
        plt.scatter(x_plot, y_plot)
        plt.ylabel("Price(1000s) dollar")
        if i == 0 :
            plt.xlabel("size(sqft)")
        elif i == 1:
            plt.xlabel("bedrooms")
        elif i == 2:
            plt.xlabel("floors")
        elif i == 3:
            plt.xlabel("age")
        plt.figure(figsize= (.5,1), dpi=10)
        plt.show()

# %%
graphing(X_train, y_train)

# %% [markdown]
# #### Cost function

# %%
def computeCost(x, y, w, b):
    m = x.shape[0]
    totalCost = 0
    for i in range(m):
        y_hat = np.dot(w,x[i]) + b
        errorSq =  (y_hat - y[i]) ** 2
        totalCost += errorSq
        
    cost = totalCost / (2*m)
    return cost

# %%
# cost = computeCost(X_train,y_train,w_init,b)

# %% [markdown]
# ### Defining Gradient Descent

# %%
def derivative(x,y,w,b):
    m = x.shape[0]
    n = x.shape[1]
    dj_dw = np.zeros((n))
    dj_db = 0
    for i in range(m):
        predicted_value = np.dot(w,x[i,:]) + b
        for j in range(n):
            err = (predicted_value - y[i]) * x[i, j]
            dj_dw[j] += err
            
        dj_db += predicted_value - y[i]
    dj_dw = dj_dw / m
    dj_db = dj_db / m
    
    return dj_dw, dj_db

# %%
def gradient_descent(x,y,w_in,b_in,derivative,iteration,computecost,alpha):
    j_history = []
    w = copy.deepcopy(w_in)
    b = copy.deepcopy(b_in)
    
    for i in range(iteration):
        
        dj_dw, dj_db = derivative(x,y,w,b)
        w = w - (alpha * dj_dw)      # w is a vector
        b = b - (alpha * dj_db)
        
        j_history.append(computecost(x,y,w,b))
    
    return b,w, j_history

# %%
b_init = 0.
w_init = np.zeros(4)
iteration = 10
alpha = 9.9e-7
b_value, w_value, cost_value = gradient_descent(X_train, y_train,w_init,b_init,derivative,iteration, computeCost,alpha)

# %%
print(b_value)
print(w_value)
print(cost_value)
# Out:
# -0.000521403796602646
# [-0.86724558 -0.00165786 -0.00091072 -0.02717454]
# [95571.39044870318, 128166.31406127565, 172064.38874957545, 231185.22665687796, 310807.65032345476, 418041.0283277199, 562460.0567685153, 756959.6649736401, 1018906.3782772357, 1371688.9407749288]

# %% [markdown]
# ### converting scientific notation to an integer for plotting

# %%
cost = []
for i in cost_value:
    cost.append(int(i))

# %% [markdown]
# ### plotting cost vs iteration

# %%
# iteration = [i for i in range(len(cost_value))]
# Cost_value = cost
# plt.plot(range(len(cost_value)), Cost_value)
# plt.show()

# %% [markdown]
# ### choosing alpha

# %%
# b_init = 0.
# w_init = np.zeros(4)
# alpha = [9e-7]
# iteration = 10

# %%
# cost_value = []
# for i in range(len(alpha)):
#     b_value, w_value, cost_value = gradient_descent(X_train, y_train,w_init,b_init,derivative,iteration, computeCost,alpha[i])
#     cost1.append(cost_value)
#     x = range(len(cost_value))
#     plt.plot(x, cost_value, label = alpha[i])
# plt.show()

# %%
b_init = 0.
w_init = np.zeros(4)
alpha = [1e-7, 0.0000009]
iteration = 10

# %%
cost0 = []
def chossingalpha(x,y,w,b,derivative,iteration,computeCost,alpha):
    for i in range(len(alpha)):
        _, _, cost_value = gradient_descent(X_train, y_train,w_init,b_init,derivative,iteration, computeCost,alpha[i])
        cost0.append(cost_value)
        x = range(len(cost_value))
        plt.plot(x, cost_value, label= alpha[i])
        
        plt.show()
        
    return cost0

# %%
cost0 = chossingalpha(X_train, y_train,w_init,b_init,derivative, iteration, computeCost, alpha)

# %% [markdown]
# ### feature Scaling  using Z Score Normalization

# %%
# defining Z Score Normalization
def zscore_norm(X):
    
    mu = np.mean(X, axis=0)
    sigma = np.std(X, axis=0)
    
    zscore = (X - mu) / sigma
    return mu, sigma, zscore

# %%
mu, sigma, zscore = zscore_norm(X_train)
# comparing peak to peak raw and normalized
print(f"peak to peak raw by columns {np.ptp(X_train, axis=0)} ")
print(f"peak to peak raw by columns {np.ptp(zscore, axis=0)} ")
# Out:
# peak to peak raw by columns [2.402e+03 4.000e+00 1.000e+00 9.500e+01]
# peak to peak raw by columns [5.83855607 6.13529646 2.05626214 3.68533012]

# %% [markdown]
# ### predicting prices using normalized data

# %%
b_init = 0.
w_init = np.zeros(4)
iteration =  1000
alpha = 1.0e-1
b_value, w_value, cost_value = gradient_descent(zscore, y_train,w_init,b_init,derivative,iteration, computeCost,alpha)

# %%
print(b_value)
print(w_value)
print(cost_value)
# Out:
# 363.1560606060604
# [110.68543496 -21.40075496 -32.70120024 -37.85828036]
# [57616.38498352908, 46637.86598966633, 37840.7858465031, 30770.033435436373, 25072.608525231677, 20472.303558771076, 16751.427136270566, 13737.390549494146, 11292.70938079506, 9307.444709971418, 7693.416855670449, 6379.728016166543, 5309.266067004093, 4435.9538373752985, 3722.571534446729, 3139.0242998818867, 2660.958417327982, 2268.652514760858, 1946.126900063071, 1680.4267160953134, 1461.0441074553153, 1279.451880998867, 1128.7267915929067, 1003.245001469835, 898.4357401391502, 810.5819477597062, 736.6588787828664, 674.2033958447794, 621.2080890954182, 576.0354851433898, 537.3485185544597, 504.0541713918694, 475.2577774631681, 450.22596544417746, 428.3566010058195, 409.15440019202117, 392.2111388150548, 377.1895869964556, 363.8104634123353, 351.8418377445472, 341.09051830415, 331.3950496384111, 322.6200160845952, 314.6514048701288, 307.3928290502747, 300.7624484021031, 294.6904570418781, 289.11703136613477, 283.9906520391478, 279.2667300559025, 274.9064801245365, 270.8759953224284, 267.14548566107163, 263.68865023164125, 260.482158307724, 257.5052194067493, 254.7392260619735, 252.16745609828996, 249.77482367207716, 247.54767033661014, 245.47358901848136, 243.54127510847647, 241.74039994036548, 240.0615027999965, 238.4958983129933, 237.03559663304537, 235.6732343192357, 234.40201417031028, 233.21565259267663, 232.10833333050488, 231.0746665914028, 230.10965276846386, 229.20865009614374, 228.36734568916125, 227.5817295050835, 226.84807084624734, 226.1628970782503, 225.5229742928929, 224.92528968521069, 224.3670354487251, 223.84559402161173, 223.35852454019496, 222.90355037594844, 222.47854764867705, 222.08153462240585, 221.71066190214813, 221.36420335957928, 221.0405477239904, 220.73819078202519, 220.4557281358092, 220.19184847432774, 219.9453273174452, 219.71502119592418, 219.4998622342285, 219.29885310594108, 219.11106233428066, 218.93561991258093, 218.7717132216931, 218.61858322316223, 218.47552090870963, 218.3418639880922, 218.21699379876827, 218.10033242207234, 217.99133999171696, 217.8895121815012, 217.79437786003612, 217.7054969011896, 217.6224581397353, 217.54487746244823, 217.47239602555442, 217.40467859008237, 217.34141196724073, 217.2823035664905, 217.22708003947176, 217.17548601341858, 217.12728290812058, 217.08224783089076, 217.0401725443725, 217.0008625023656, 216.96413594916896, 216.92982307824926, 216.89776524630688, 216.86781423909127, 216.83983158554244, 216.81368791707678, 216.78926236903695, 216.76644202152892, 216.74512137704505, 216.72520187245877, 216.70659142311666, 216.6892039969216, 216.67295921642867, 216.65778198711064, 216.6436021500696, 216.6303541575876, 216.61797677001107, 216.60641277256767, 216.5956087108012, 216.58551464340232, 216.5760839112908, 216.56727292187674, 216.55904094750787, 216.5513499371641, 216.5441643405346, 216.53745094365578, 216.53117871535633, 216.5253186637955, 216.5198437024307, 216.51472852479642, 216.5099494875137, 216.5054845009887, 216.50131292729642, 216.49741548477587, 216.4937741588958, 216.49037211897905, 216.48719364040105, 216.48422403189937, 216.4814495676642, 216.47885742388863, 216.4764356194918, 216.47417296073624, 216.47205898948545, 216.47008393486297, 216.4682386680862, 216.4665146602709, 216.46490394300847, 216.4633990715321, 216.4619930903058, 216.46067950087343, 216.45945223182306, 216.45830561072057, 216.45723433789314, 216.4562334619319, 216.45529835680546, 216.45442470047857, 216.45360845493386, 216.45284584750902, 216.4521333534572, 216.45146767965716, 216.45084574939108, 216.4502646881241, 216.4497218102168, 216.44921460651435, 216.44874073274687, 216.44829799869493, 216.44788435806674, 216.4474978990385, 216.4471368354204, 216.44679949839852, 216.44648432882252, 216.44618986999924, 216.44591476095957, 216.44565773016865, 216.44541758964797, 216.44519322948537, 216.44498361270462, 216.44478777047183, 216.44460479761995, 216.44443384846167, 216.4442741328834, 216.44412491269247, 216.44398549820488, 216.44385524505785, 216.44373355123204, 216.443619 ...

# %%
w_value
b_value
# Out:
# 363.1560606060604

# %% [markdown]
# ### model

# %%
def model(x,w,b):
    m= zscore.shape[0]
    predicted_y = np.zeros(m)
    for i in range(m):
        predicted_y[i] = np.dot(w,x[i]) + b
    
    return predicted_y

# %%
predicted = model(zscore,w_value,b_value)
print(w_value)
print(b_value)
predicted
# Out:
# [110.68543496 -21.40075496 -32.70120024 -37.85828036]
# 363.1560606060604
# array([294.06582572, 486.87047052, 388.27454702, 492.49817679,
#        419.15559933, 222.79309636, 524.51789652, 268.40795634,
#        684.85533958, 181.78488987, 317.91264256, 480.54200271,
#        409.80405085, 393.47302636, 286.53425537, 323.27647205,
#        405.41684865, 436.97395891, 269.62975964, 500.35003838,
#        329.12465075, 389.02104289, 551.32603506, 241.56938247,
#        296.05282567, 281.41256293, 216.88483036, 490.03586941,
#        228.28254448, 341.34000765, 290.16593658, 491.52320451,
#        239.58136139, 598.10730501, 383.68624814, 452.86975365,
#        401.22072132, 405.91051069, 173.51752043, 424.97805331,
#        434.44721643, 276.13094771, 228.28254448, 447.96383967,
#        488.33910484, 330.63668943, 466.79690305, 221.62807033,
#        386.81191551, 456.28198357, 371.60720665, 470.02708322,
#        310.7391689 , 425.47171535, 392.25122306, 347.44902416,
#        340.04409358, 470.46231297, 243.44117284, 297.85777587,
#        272.78915572, 249.53212247, 297.53381178, 334.42239012,
#        375.0815417 , 290.15358479, 228.28254448, 621.58075059,
#        352.52731224, 511.31888839, 364.00217609, 361.88853638,
#        297.53381178, 406.8667822 , 288.69730226, 386.59613706,
#        487.59861178, 261.79292599, 259.3459927 , 428.20188449,
#        237.82581836, 356.50766112, 340.59951459, 390.78258873,
#        380.72159977, 219.77767352, 434.44721643, 243.19434182,
#        466.79690305, 185.82054631, 341.09317663, 411.47010902,
#        445.27340204, 231.66002456, 330.63668943, 408.85045548,
#        405.91051069, 350.61442306, 274.30387054])

# %% [markdown]
# ### Actual vs Predicted

# %%
for i in range(X_train.shape[1]):
    plt.scatter(X_train[:, i], y_train)
    plt.scatter(X_train[:, i], predicted)
    plt.ylabel("Price(1000s) dollar")
    if i == 0 :
        plt.xlabel("size(sqft)")
    elif i == 1:
        plt.xlabel("bedrooms")
    elif i == 2:
        plt.xlabel("floors")
    elif i == 3:
        plt.xlabel("age")
    plt.figure(figsize= (.5,1), dpi=10)
    plt.show()

# %% [markdown]
# ### predicting new house prices

# %%
x_house = np.array([1200, 3, 1, 40])

# Any predictions using the parameters learned from a normalized training set must also be normalized.
# can use previous mean and sigma, don't need to find mean again with new data
x_norm = (x_house - mu) / sigma
print(x_norm)

house_price = np.dot(w_value, x_norm) + b_value
print(f"estimates price will be: ${house_price * 1000}")
# Out:
# [-0.53085148  0.43380884 -0.78927234  0.06269567]
# estimates price will be: $318551.29896558716
